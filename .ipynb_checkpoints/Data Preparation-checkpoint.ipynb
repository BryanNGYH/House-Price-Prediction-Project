# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import re

# %matplotlib inline

pd.set_option('max_rows',500)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[71], line 9
#       5 import re
#       7 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 9 pd.set_option('max_rows',500)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_config\config.py:272, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     271 def __call__(self, *args, **kwds) -> T:
# --> 272     return self.__func__(*args, **kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_config\config.py:167, in _set_option(*args, **kwargs)
#     164     raise TypeError(f'_set_option() got an unexpected keyword argument "{kwarg}"')
#     166 for k, v in zip(args[::2], args[1::2]):
# --> 167     key = _get_single_key(k, silent)
#     169     o = _get_registered_option(key)
#     170     if o and o.validator:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_config\config.py:134, in _get_single_key(pat, silent)
#     132     raise OptionError(f"No such keys(s): {repr(pat)}")
#     133 if len(keys) > 1:
# --> 134     raise OptionError("Pattern matched multiple keys")
#     135 key = keys[0]
#     137 if not silent:
#
# OptionError: Pattern matched multiple keys

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv('Bengaluru_House_Data.csv')
print('Shape of the dataframe:',df.shape)
print('\n----------------------------------------------------------------------------------------------\n')
print(df.info())
print('\n----------------------------------------------------------------------------------------------\n')
df.head()
# Out:
# Shape of the dataframe: (13320, 9)
#
# ----------------------------------------------------------------------------------------------
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB
# None
#
# ----------------------------------------------------------------------------------------------
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %% [markdown]
# ### "total_sft" & size column should be float or int, but it is object data type. Hence, probably something is weird about this column

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Handling missing value

# %%
print('Number of missing data for each columns\n',df.isnull().sum())
print('\n----------------------------------------------------------------------------------------------\n')
print('Percentage of missing data for each columns\n',round(df.isnull().sum()/len(df)*100,2))
# Out:
# Number of missing data for each columns
#  area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64
#
# ----------------------------------------------------------------------------------------------
#
# Percentage of missing data for each columns
#  area_type        0.00
# availability     0.00
# location         0.01
# size             0.12
# society         41.31
# total_sqft       0.00
# bath             0.55
# balcony          4.57
# price            0.00
# dtype: float64

# %% [markdown]
# 'Society' has a lot of missing values and don't have meaningful information for the model. We will remove this column.

# %%
"""
df = df.drop(columns=['society'])
same thing
"""
df = df.drop(['society'],axis=1)
#df1.shape

# %%
df.nunique()
# Out:
# area_type          4
# availability      81
# location        1305
# size              31
# society         2688
# total_sqft      2117
# bath              19
# balcony            4
# price           1994
# dtype: int64

# %%
plt.hist(df.balcony)
plt.xlabel('number of balcony',fontsize=20)
plt.ylabel('count',fontsize=20)
plt.title('distribution of balcony count',fontsize=24)
plt.show()

# %% [markdown]
# "balcony" has a roughly gaussian distribution, we will take the mean value of balcony to impute the missing value

# %%
balcony_mean = np.floor(df.balcony.mean())
# balcony_mode = df.balcony.mode()
df['balcony'].fillna(balcony_mean, inplace=True)
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %% [markdown]
# Remaining missing value is insignificant, we will just drop them.

# %%
df.dropna(axis=0,inplace=True)
df.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# society         0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
"""
doing the same thing
"""
# df.groupby('area_type')['area_type'].agg('count')
df.area_type.value_counts()
# Out:
# area_type
# Super built-up  Area    6188
# Built-up  Area          1207
# Plot  Area               298
# Carpet  Area              54
# Name: count, dtype: int64

# %%
plt.scatter(df['area_type'],df['price'],marker='*')
plt.xlabel('area type')
plt.ylabel('price')
plt.title('scatter plot of area type against price')
# Out:
# Text(0.5, 1.0, 'scatter plot of area type against price')

# %% [markdown]
# ## Handling Duplicated Rows

# %%
print(df.duplicated().sum())
print(df.shape)
# Out:
# 355
# (7747, 9)

# %%
df.drop_duplicates(inplace=True)
print(df.shape)
# Out:
# (7392, 9)

# %% [markdown]
# # Feature Engineering

# %%
df.nunique()
# Out:
# area_type          4
# availability      76
# location         647
# size              19
# society         2667
# total_sqft      1749
# bath              11
# balcony            4
# price           1536
# dtype: int64

# %% [markdown]
# since 'size' column have word, create another column with only the number of room

# %%
df['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '3 Bedroom', '1 RK',
#        '1 BHK', '5 BHK', '11 BHK', '5 Bedroom', '9 BHK', '6 Bedroom',
#        '2 Bedroom', '9 Bedroom', '6 BHK', '7 BHK', '10 Bedroom',
#        '8 Bedroom', '18 Bedroom'], dtype=object)

# %%
b = 'x bhk'
x = b.split(' ')
x
# Out:
# ['x', 'bhk']

# %%
df['rooms'] = df['size'].apply(lambda x : int(x.split(' ')[0]) )
df.drop(columns='size',inplace=True)

# %%
# df['bedrooms'] = df['size'].apply(lambda x : int(x.split(' ')[0]) )
# # df.drop(columns='size',inplace=True)

# %%
# """
# def bhk(x):
#     x = str(x)
#     y = x[0]
#     return y
    
# df.bhk = df.size.apply(bhk)
# """
# df['bhk'] = df['size'].apply(lambda x : int(x.split(' ')[0]))

# %%
df.head()
# Out:
#               area_type   availability                  location  society  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II  Coomee
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  Theanmp
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli  Soiewre
# 5  Super built-up  Area  Ready To Move                Whitefield  DuenaTa
# 6  Super built-up  Area         18-May          Old Airport Road  Jaades
#
#   total_sqft  bath  balcony   price  rooms
# 0       1056   2.0      1.0   39.07      2
# 1       2600   5.0      3.0  120.00      4
# 3       1521   3.0      1.0   95.00      3
# 5       1170   2.0      1.0   38.00      2
# 6       2732   4.0      1.0  204.00      4

# %%
df.rooms.value_counts()
# Out:
# rooms
# 2     3275
# 3     3113
# 4      595
# 1      350
# 5       42
# 6        9
# 9        3
# 11       1
# 7        1
# 10       1
# 8        1
# 18       1
# Name: count, dtype: int64

# %%
plt.subplot(1,2,1)
plt.boxplot(df.rooms)
plt.subplot(1,2,2)
plt.hist(df.rooms)
# Out:
# (array([3.625e+03, 3.708e+03, 5.100e+01, 1.000e+00, 4.000e+00, 2.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([ 1. ,  2.7,  4.4,  6.1,  7.8,  9.5, 11.2, 12.9, 14.6, 16.3, 18. ]),
#  <BarContainer object of 10 artists>)

# %%
df[df.rooms >= 10]
# Out:
#                   area_type   availability       location  society total_sqft  \
# 459    Super built-up  Area  Ready To Move   1 Giri Nagar  Bancyri       5000
# 3523             Plot  Area  Ready To Move         Jigani  Mae 2ra       1200
# 11559            Plot  Area         18-Apr  1Kasavanhalli  HMwerCo       1200
#
#        bath  balcony  price  rooms
# 459     9.0      3.0  360.0     11
# 3523   10.0      1.0  105.0     10
# 11559  18.0      1.0  200.0     18

# %% [markdown]
# # 'total_sqft'

# %%
df.total_sqft.unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
def is_float(x):
    try:
        float(x)
        return True
    except:
        return False
    return True

# %%
df[~df['total_sqft'].apply(is_float)].head(50)
# Out:
#                  area_type   availability               location  society  \
# 30    Super built-up  Area         19-Dec              Yelahanka  LedorSa
# 122   Super built-up  Area         18-Mar                 Hebbal  SNontle
# 137   Super built-up  Area         19-Mar     8th Phase JP Nagar  Vaarech
# 165   Super built-up  Area         18-Dec               Sarjapur  Kinuerg
# 188   Super built-up  Area  Ready To Move               KR Puram  MCvarar
# 549   Super built-up  Area         18-Sep            Hennur Road  Shxorm
# 661   Super built-up  Area  Ready To Move              Yelahanka  Rarthne
# 672         Built-up  Area         18-Mar           Bettahalsoor  Toainnt
# 772   Super built-up  Area         20-Dec  Banashankari Stage VI  Brens7
# 850   Super built-up  Area         22-Dec      Bannerghatta Road  PrarePa
# 886   Super built-up  Area         18-Jun             Chandapura  SuVue S
# 927   Super built-up  Area         18-Dec            Thanisandra  Omter A
# 959   Super built-up  Area  Ready To Move            Kammasandra  Puitea
# 990   Super built-up  Area  Ready To Move               Sarjapur  DSousyl
# 1178  Super built-up  Area         20-Dec              Yelahanka  Un 46th
# 1183  Super built-up  Area         18-Aug            Magadi Road  Vrenty
# 1187  Super built-up  Area         18-Mar            Thanisandra  SLityee
# 1484          Carpet  Area         18-Mar                 Hebbal  Arcia S
# 1542  Super built-up  Area         19-Jul         Sarjapur  Road  Sasta S
# 1614  Super built-up  Area  Ready To Move         Sarjapur  Road  DSndsod
# 1643  Super built-up  Area         18-May         Talaghattapura  Sodgere
# 1683  Super built-up  Area  Ready To Move        Old Madras Road  Brica E
# 1694  Super built-up  Area         18-Dec               JP Nagar  Pehtsa
# 1712            Plot  Area  Ready To Move       Singena Agrahara  CoiewSy
# 1743  Super built-up  Area         19-Mar              Hosa Road  Sosisic
# 1821            Plot  Area  Ready To Move               Sarjapur  Inensba
# 2088  Super built-up  Area  Ready To Move           Yeshwanthpur  Prthand
# 2128  Super built-up  Area         20-Dec         Kanakpura Road  GolusLi
# 2228          Carpet  Area  Ready To Move               KR Puram  Jahidva
# 2265  Super built-up  Area  Ready To Move        Old Madras Road  Brica E
# 2301  Super built-up  Area         18-Mar              Hosa Road  Akvam P
# 2310  Super built-up  Area  Ready To Move             Whitefield  Haestt
# 2396  Super built-up  Area         20-Jan               Balagere  Soresea
# 2431  Super built-up  Area  Ready To Move              EPIP Zone  BrontLa
# 2575  Super built-up  Area         18-Dec             Whitefield  Prtates
# 2587  Super built-up  Area         21-Jun            Tumkur Road  Coowsri
# 2713  Super built-up  Area  Ready To Move               KR Puram  MCvarar
# 2716  Super built-up  Area         18-Mar               JP Nagar  Shestut
# 2881        Built-up  Area  Ready To Move     Volagerekallahalli  PSterAs
# 2916  Super built-up  Area         18-Nov            Thanisandra  Bhe 2ko
# 2920  Super built-up  Area         18-Jun            Mysore Road  Gopia O
# 3174  Super built-up  Area         22-May                 Jakkur  SoineC
# 3215  Super built-up  Area         18-Sep               KR Puram  MCnexva
# 3285            Plot  Area         18-May             Whitefield  Prtates
# 3356  Super built-up  Area  Ready To Move              Yelahanka  Niareum
# 3364  Super built-up  Area         19-Dec             Whitefield  Goted U
# 3468  Super built-up  Area  Ready To Move           Yeshwanthpur  VSlistr
# 3890  Super built-up  Area         21-Jun            Tumkur Road  Coowsri
# 3947        Built-up  Area         18-May         Sarjapur  Road  Cetattu
# 3984  Super built-up  Area  Ready To Move            Uttarahalli  Niiewem
#
#              total_sqft  bath  balcony    price  rooms
# 30          2100 - 2850   4.0      0.0  186.000      4
# 122         3067 - 8156   4.0      0.0  477.000      4
# 137         1042 - 1105   2.0      0.0   54.005      2
# 165         1145 - 1340   2.0      0.0   43.490      2
# 188         1015 - 1540   2.0      0.0   56.800      2
# 549         1195 - 1440   2.0      0.0   63.770      2
# 661         1120 - 1145   2.0      0.0   48.130      2
# 672         3090 - 5002   4.0      0.0  445.000      4
# 772         1160 - 1195   2.0      0.0   59.935      2
# 850         1115 - 1130   2.0      0.0   58.935      2
# 886           520 - 645   1.0      0.0   15.135      1
# 927         1000 - 1285   2.0      0.0   43.415      2
# 959           650 - 665   1.0      0.0   18.410      1
# 990           633 - 666   1.0      0.0   17.535      1
# 1178        1445 - 1455   3.0      0.0   65.255      3
# 1183         884 - 1116   2.0      0.0   46.500      2
# 1187         850 - 1093   2.0      0.0   36.435      2
# 1484    547.34 - 827.31   2.0      0.0   42.720      2
# 1542          580 - 650   1.0      0.0   17.835      1
# 1614        3425 - 3435   6.0      0.0  228.500      4
# 1643        1804 - 2273   3.0      0.0  120.000      3
# 1683        3630 - 3800   6.0      0.0  224.500      4
# 1694        4000 - 5249   4.0      0.0  314.500      4
# 1712      1500Sq. Meter   3.0      1.0   95.000      3
# 1743    142.61Sq. Meter   3.0      1.0  115.000      3
# 1821      1574Sq. Yards   3.0      1.0   76.000      3
# 2088        1250 - 1305   2.0      0.0   95.815      2
# 2128          670 - 980   1.0      0.0   36.290      1
# 2228  1005.03 - 1252.49   3.0      0.0   47.405      3
# 2265        3630 - 3800   6.0      0.0  200.500      4
# 2301        1004 - 1204   2.0      0.0   36.430      2
# 2310    361.33Sq. Yards   4.0      1.0  270.000      4
# 2396          645 - 936   1.0      0.0   41.900      1
# 2431        2710 - 3360   5.0      0.0  200.000      4
# 2575        2830 - 2882   5.0      0.0  145.500      4
# 2587          596 - 804   1.0      0.0   30.090      1
# 2713        1255 - 1863   3.0      0.0   69.315      3
# 2716        1300 - 1405   2.0      0.0   93.865      2
# 2881       117Sq. Yards   2.0      2.0   38.000      2
# 2916         934 - 1437   2.0      0.0   58.680      2
# 2920         980 - 1030   2.0      0.0   35.175      2
# 3174  2249.81 - 4112.19   4.0      0.0  260.500      4
# 3215        1070 - 1315   2.0      0.0   51.220      2
# 3285       500Sq. Yards   4.0      2.0  378.000      4
# 3356        2806 - 3019   6.0      0.0  125.500      4
# 3364          613 - 648   1.0      0.0   32.790      1
# 3468          704 - 730   2.0      0.0   49.475      2
# 3890        1210 - 1477   3.0      0.0   57.760      3
# 3947        3369 - 3464   6.0      0.0  143.000      4
# 3984        1125 - 1500   3.0      0.0   51.190      3

# %%
def unit_comversion_to_sqft(x):
    tokens = x.split('-')
    if len(tokens) == 2:
        return ( float(tokens[0]) + float(tokens[1]) ) / 2
    else:
        return x

# %%
def unit_comversion_to_sqft1(x):
    conversion_factors={
        'sq. meter': 10.7639,
        'sq. yards': 9,
        'acres': 43560,
        'guntha': 1089,
        'cents': 435.56,
        'grounds': 2400,
        'perch': 272.25
    }
    try:
        match = re.search(r'(\d+\.?\d*)\s*(\w+\.?\s*\w*)', x)
        if match:
            num = float(match.group(1))
            unit = match.group(2).lower()
            
            if unit in conversion_factors:
                return num * conversion_factors[unit]
            else:
                return x
        else:
            return x
    except:
        return x

# %%
 df.total_sqft =  df.total_sqft.apply(unit_comversion_to_sqft)

# %%
 df.total_sqft =  df.total_sqft.apply(unit_comversion_to_sqft1)

# %%
df[~df.total_sqft.apply(is_float)]
# Out:
# Empty DataFrame
# Columns: [area_type, availability, location, society, total_sqft, bath, balcony, price, rooms]
# Index: []

# %%
df.head(50)
# Out:
#                area_type   availability                  location  society  \
# 0   Super built-up  Area         19-Dec  Electronic City Phase II  Coomee
# 1             Plot  Area  Ready To Move          Chikka Tirupathi  Theanmp
# 3   Super built-up  Area  Ready To Move        Lingadheeranahalli  Soiewre
# 5   Super built-up  Area  Ready To Move                Whitefield  DuenaTa
# 6   Super built-up  Area         18-May          Old Airport Road  Jaades
# 7   Super built-up  Area  Ready To Move              Rajaji Nagar  Brway G
# 11            Plot  Area  Ready To Move                Whitefield  Prrry M
# 12  Super built-up  Area  Ready To Move        7th Phase JP Nagar  Shncyes
# 14            Plot  Area  Ready To Move                  Sarjapur  Skityer
# 15  Super built-up  Area  Ready To Move               Mysore Road  PrntaEn
# 16  Super built-up  Area  Ready To Move             Bisuvanahalli  Prityel
# 17  Super built-up  Area  Ready To Move     Raja Rajeshwari Nagar  GrrvaGr
# 18  Super built-up  Area  Ready To Move     Ramakrishnappa Layout  PeBayle
# 21  Super built-up  Area         19-Dec                Binny Pete  She 2rk
# 22            Plot  Area  Ready To Move               Thanisandra  Soitya
# 24  Super built-up  Area         18-Nov               Thanisandra  Bhe 2ko
# 26  Super built-up  Area  Ready To Move           Electronic City  Itelaa
# 28  Super built-up  Area         17-Oct          Ramagondanahalli  ViistLa
# 29  Super built-up  Area  Ready To Move           Electronic City  KBityo
# 30  Super built-up  Area         19-Dec                 Yelahanka  LedorSa
# 31  Super built-up  Area  Ready To Move             Bisuvanahalli  Prityel
# 32  Super built-up  Area  Ready To Move                    Hebbal  Mahosya
# 33  Super built-up  Area  Ready To Move     Raja Rajeshwari Nagar  GrrvaGr
# 34        Built-up  Area  Ready To Move             Kasturi Nagar  Kantsce
# 35  Super built-up  Area         21-Dec            Kanakpura Road  PrarePa
# 37  Super built-up  Area  Ready To Move              Kundalahalli  Dieldli
# 40        Built-up  Area  Ready To Move             Murugeshpalya  Gentson
# 41  Super built-up  Area         19-Dec            Sarjapur  Road  Soini T
# 42  Super built-up  Area  Ready To Move               Ganga Nagar  Ceove G
# 44  Super built-up  Area         19-Sep            Kanakpura Road  Soazak
# 46  Super built-up  Area  Ready To Move              Doddathoguru  LancyRe
# 47  Super built-up  Area         20-Sep                Whitefield  Goted U
# 50  Super built-up  Area  Ready To Move              Adarsh Nagar  Bhncyis
# 51  Super built-up  Area         18-Mar               Bhoganhalli  Rosha I
# 52        Built-up  Area  Ready To Move                Whitefield  Suent V
# 53  Super built-up  Area  Ready To Move      Lakshminarayana Pura  RothaVa
# 54  Super built-up  Area  Ready To Move                 Yelahanka  NCowsar
# 55  Super built-up  Area  Ready To Move                Begur Road  Dhalsh
# 57  Super built-up  Area  Ready To Move     Ramakrishnappa Layout  PeBayle
# 61  Super built-up  Area  Ready To Move               Ganga Nagar  Laavevi
# 62            Plot  Area  Ready To Move                Whitefield  Chranya
# 63        Built-up  Area  Ready To Move                   Varthur  HioraTr
# 66  Super built-up  Area         18-Apr                    Gunjur  BMineis
# 71  Super built-up  Area         20-Aug                Begur Road  Pruthg
# 72  Super built-up  Area  Ready To Move               Hegde Nagar  Sonosty
# 73  Super built-up  Area         18-Apr              Haralur Road  SNnia E
# 74  Super built-up  Area  Ready To Move               Hennur Road  Anavi B
# 77        Built-up  Area  Ready To Move        Cholanayakanahalli  Viony H
# 80  Super built-up  Area  Ready To Move      Kodanda Reddy Layout  AdentEl
# 82  Super built-up  Area         19-Mar                 Yelahanka  Niareum
#
#    total_sqft  bath  balcony   price  rooms
# 0        1056   2.0      1.0   39.07      2
# 1        2600   5.0      3.0  120.00      4
# 3        1521   3.0      1.0   95.00      3
# 5        1170   2.0      1.0   38.00      2
# 6        2732   4.0      1.0  204.00      4
# 7        3300   4.0      1.0  600.00      4
# 11       2785   5.0      3.0  295.00      4
# 12       1000   2.0      1.0   38.00      2
# 14       2250   3.0      2.0  148.00      3
# 15       1175   2.0      2.0   73.50      2
# 16       1180   3.0      2.0   48.00      3
# 17       1540   3.0      3.0   60.00      3
# 18       2770   4.0      2.0  290.00      3
# 21       1755   3.0      1.0  122.00      3
# 22       2800   5.0      2.0  380.00      4
# 24        510   1.0      0.0   25.25      1
# 26        660   1.0      1.0   23.10      2
# 28       1151   2.0      2.0   48.77      2
# 29       1025   2.0      1.0   47.00      3
# 30     2475.0   4.0      0.0  186.00      4
# 31       1075   2.0      1.0   35.00      3
# 32       1760   2.0      2.0  123.00      3
# 33       1693   3.0      3.0   57.39      3
# 34       1925   3.0      1.0  125.00      3
# 35        700   2.0      1.0   36.00      2
# 37       1724   3.0      2.0  125.00      3
# 40       1296   2.0      1.0   81.00      2
# 41       1254   3.0      2.0   38.00      3
# 42        600   1.0      0.0   38.00      1
# 44    1330.74   2.0      2.0   91.79      2
# 46        970   2.0      0.0   33.00      2
# 47       1459   2.0      1.0   94.82      2
# 50       1270   2.0      1.0   50.00      2
# 51       1670   3.0      1.0   99.00      3
# 52       2010   3.0      2.0   91.00      3
# 53       1185   2.0      2.0   75.00      2
# 54       1600   2.0      3.0   75.00      3
# 55       1200   2.0      2.0   44.00      2
# 57       1500   2.0      2.0  185.00      2
# 61        845   2.0      1.0   55.00      2
# 62       5700   5.0      3.0  650.00      4
# 63       1160   2.0      2.0   44.00      2
# 66       1140   2.0      3.0   43.00      2
# 71       1358   2.0      1.0   80.58      2
# 72       1569   3.0      1.0  101.00      3
# 73       1240   2.0      1.0   70.00      2
# 74       2089   3.0      2.0  140.00      3
# 77       2511   3.0      3.0  205.00      3
# 80       1660   2.0      2.0  105.00      3
# 82       1326   2.0      2.0   78.00      2

# %% [markdown]
# ### availability

# %%
df.availability.unique()
# Out:
# array(['19-Dec', 'Ready To Move', '18-May', '18-Nov', '17-Oct', '21-Dec',
#        '19-Sep', '20-Sep', '18-Mar', '18-Apr', '20-Aug', '19-Mar',
#        '17-Sep', '17-Aug', '19-Apr', '22-Dec', '18-Aug', '19-Jan',
#        '17-Jul', '18-Jul', '18-Dec', '21-Jun', '18-Sep', '17-May',
#        '17-Jun', '18-Oct', '21-May', '20-Dec', '18-Jun', '16-Mar',
#        '22-Jun', '17-Dec', '21-Feb', '19-May', '17-Nov', '20-Oct',
#        '20-Jun', '18-Feb', '19-Feb', '21-Oct', '21-Jan', '17-Mar',
#        '19-Jun', '17-Apr', '22-May', '19-Oct', '21-Jul', '21-Nov',
#        '21-Mar', '19-Jul', '20-Jan', '21-Sep', '18-Jan', '20-Mar',
#        '19-Nov', '15-Nov', '15-Jun', '19-Aug', '20-May', '20-Nov',
#        '20-Jul', '15-Oct', '20-Feb', '15-Dec', '21-Aug', '16-Oct',
#        '22-Nov', '16-Dec', '15-Aug', '17-Jan', '16-Nov', '20-Apr',
#        '22-Jan', '16-Jan', '17-Feb', '14-Jul'], dtype=object)

# %%
df.availability = df.availability.apply(lambda x : 1 if x == 'Ready To Move' else 0)
df.availability.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.head()
# Out:
#               area_type  availability                  location  society  \
# 0  Super built-up  Area             0  Electronic City Phase II  Coomee
# 1            Plot  Area             1          Chikka Tirupathi  Theanmp
# 3  Super built-up  Area             1        Lingadheeranahalli  Soiewre
# 5  Super built-up  Area             1                Whitefield  DuenaTa
# 6  Super built-up  Area             0          Old Airport Road  Jaades
#
#   total_sqft  bath  balcony   price  rooms
# 0       1056   2.0      1.0   39.07      2
# 1       2600   5.0      3.0  120.00      4
# 3       1521   3.0      1.0   95.00      3
# 5       1170   2.0      1.0   38.00      2
# 6       2732   4.0      1.0  204.00      4

# %%
df.location = df.location.apply(lambda x : x.strip())
print(df['location'].nunique())
location_stats = df.location.value_counts()
location_stats
# Out:
# 639
# location
# Whitefield         399
# Sarjapur  Road     316
# Electronic City    231
# Thanisandra        211
# Kanakpura Road     198
#                   ...
# Gattigere            1
# Kamakshipalya        1
# HAL 2nd Stage        1
# S R Layout           1
# Abshot Layout        1
# Name: count, Length: 639, dtype: int64

# %%
len(location_stats[location_stats<=10])
# Out:
# 1027

# %% [markdown]
# label location with less than 10 data points as "others", by doing this we reduce the number of categories.

# %%
location_less_than_11 = location_stats[location_stats<=10]
df.location = df.location.apply(lambda x : 'others' if x in location_less_than_11 else x)
df.location.nunique()
# Out:
# 145

# %% [markdown]
# # Outliers Removal

# %% [markdown]
# Create a new feature "price per sqft" to remove the outlier

# %%
df['price_per_sqft'] = df['price']*100000/df['total_sqft']
df.head()
# Out:
#               area_type                  location  total_sqft  bath  balcony  \
# 0  Super built-up  Area  Electronic City Phase II      1056.0   2.0      1.0
# 1            Plot  Area          Chikka Tirupathi      2600.0   5.0      3.0
# 2        Built-up  Area               Uttarahalli      1440.0   2.0      3.0
# 3  Super built-up  Area        Lingadheeranahalli      1521.0   3.0      1.0
# 4  Super built-up  Area                  Kothanur      1200.0   2.0      1.0
#
#     price  bhk  ready_to_move  price_per_sqft
# 0   39.07    2              0     3699.810606
# 1  120.00    4              1     4615.384615
# 2   62.00    3              1     4305.555556
# 3   95.00    3              1     6245.890861
# 4   51.00    2              1     4250.000000

# %%
df = df[~(df.total_sqft/df.bhk<300)]
df.shape
# Out:
# (11501, 9)

# %%
import seaborn as sns
import re

# %%
df_or = df.copy()

# %%
# df_or_numerical = df_or.select_dtypes(exclude=['object'])
# plt.subplot()
# for feature in df_or_numerical:
#     sns.distplot(df_or[feature])
#     plt.show()
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df_or is your DataFrame

df_or_numerical = df_or.select_dtypes(exclude=['object'])
num_features = df_or_numerical.columns

# Set the number of columns for subplots
num_cols = 3

# Calculate the number of rows needed
num_rows = (len(num_features) + num_cols - 1) // num_cols

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 4*num_rows))
fig.suptitle('Distribution Plots for Numerical Features')

# Flatten the axes for easy iteration
axes = axes.flatten()

# Iterate over numerical features and plot in subplots
for i, feature in enumerate(num_features):
    sns.distplot(df_or[feature], ax=axes[i])
    axes[i].set_title(feature)
    axes[i].set_xlabel(None)  # Optional: Remove x-axis label for clarity

# Remove empty subplots if any
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

# Adjust layout
fig.tight_layout(rect=[0, 0, 1, 0.96])

# Show the plot
plt.show()
# Out:
# C:\Users\lovep\AppData\Local\Temp\ipykernel_10552\2423585245.py:30: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_or[feature], ax=axes[i])
# C:\Users\lovep\AppData\Local\Temp\ipykernel_10552\2423585245.py:30: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_or[feature], ax=axes[i])
# C:\Users\lovep\AppData\Local\Temp\ipykernel_10552\2423585245.py:30: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_or[feature], ax=axes[i])
# C:\Users\lovep\AppData\Local\Temp\ipykernel_10552\2423585245.py:30: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_or[feature], ax=axes[i])
# C:\Users\lovep\AppData\Local\Temp\ipykernel_10552\2423585245.py:30: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_or[feature], ax=axes[i])
# C:\Users\lovep\AppData\Local\Temp\ipykernel_10552\2423585245.py:30: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_or[feature], ax=axes[i])
# C:\Users\lovep\AppData\Local\Temp\ipykernel_10552\2423585245.py:30: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_or[feature], ax=axes[i])

# %%
df.price_per_sqft.describe()
# Out:
# count     11459.000000
# mean       6269.286447
# std        4053.678888
# min         267.829813
# 25%        4229.565530
# 50%        5294.117647
# 75%        6878.010822
# max      176470.588235
# Name: price_per_sqft, dtype: float64

# %%
def remove_pps_outliers(df):
    df_out = pd.DataFrame()
    for key, subdf in df.groupby('location'):
        mean = np.mean(subdf.price_per_sqft)
        std = np.std(subdf.price_per_sqft)
        reduced_df = subdf[(subdf.price_per_sqft>(mean-std)) & (subdf.price_per_sqft<=(mean+std))]
        df_out = pd.concat([df_out,reduced_df],ignore_index=True)
    return df_out

# %%
df1 = remove_pps_outliers(df)
df1.shape
# Out:
# (9405, 9)

# %%
def plot_scatter_chart(df,location):
    bhk2 = df[(df.location==location) & (df.bhk ==2)]
    bhk3 = df[(df.location==location) & (df.bhk ==3)]
    matplotlib.rcParams['figure.figsize'] = (15,10)
    plt.scatter(bhk2.total_sqft, bhk2.price,color='b',label='2 BHK', s=70)
    plt.scatter(bhk3.total_sqft, bhk3.price,color='r',label='3 BHK', s=70)
    plt.xlabel('total_sqft')
    plt.ylabel('price')
    plt.title(location)
    plt.legend()

# %%
plot_scatter_chart(df1,"Rajaji Nagar")

# %%
def remove_bhk_outliers(df):
    exclude_indices = np.array([])
    for locations, location_df in df.groupby('location'):
        bhk_stats = {}
        for bhk, bhk_df in location_df.groupby('bhk'):
            bhk_stats[bhk]={
                'mean' : np.mean(bhk_df.price_per_sqft),
                'std' : np.std(bhk_df.price_per_sqft),
                'count' : bhk_df.shape[0]
            }
        for bhk,bhk_df in location_df.groupby('bhk'):
            stats= bhk_stats.get(bhk-1)
            if stats and stats['count']>5:
                exclude_indices = np.append(exclude_indices,bhk_df[bhk_df.price_per_sqft<(stats['mean'])].index.values)
    return df.drop(exclude_indices,axis='index')

# %%
df1 = remove_bhk_outliers(df1)
df1.shape
# Out:
# (6662, 9)

# %%
plot_scatter_chart(df1,'Hebbal')

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=(20,10)
plt.hist(df1.price_per_sqft,rwidth=0.8)
plt.xlabel('Price per square feet')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.hist(df1.bath,rwidth=0.8)
plt.xlabel('Number of bathroom')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df1 = df1[df1.bath<df1.bhk+2]
df1.shape
# Out:
# (6594, 9)

# %%
df_out = df1.drop(['price_per_sqft'],axis=1)

# %%
df_out.head()
# Out:
#               area_type             location  total_sqft  bath  balcony  \
# 0  Super built-up  Area  1st Block Jayanagar      2850.0   4.0      1.0
# 1  Super built-up  Area  1st Block Jayanagar      1630.0   3.0      2.0
# 2  Super built-up  Area  1st Block Jayanagar      1875.0   2.0      3.0
# 3        Built-up  Area  1st Block Jayanagar      1200.0   2.0      0.0
# 4  Super built-up  Area  1st Block Jayanagar      1235.0   2.0      2.0
#
#    price  bhk  ready_to_move
# 0  428.0    4              0
# 1  194.0    3              0
# 2  235.0    3              1
# 3  130.0    3              0
# 4  148.0    2              0

# %% [markdown]
# # Save the cleaned data in a new csv file

# %%
df_out.to_csv('data/Bengaluru_House_Data_cleaned.csv',index=False)

# %%
pd.read_csv('data/Bengaluru_House_Data_cleaned.csv')
# Out:
#                  area_type             location  total_sqft  bath  balcony  \
# 0     Super built-up  Area  1st Block Jayanagar      2850.0   4.0      1.0
# 1     Super built-up  Area  1st Block Jayanagar      1630.0   3.0      2.0
# 2     Super built-up  Area  1st Block Jayanagar      1875.0   2.0      3.0
# 3           Built-up  Area  1st Block Jayanagar      1200.0   2.0      0.0
# 4     Super built-up  Area  1st Block Jayanagar      1235.0   2.0      2.0
# ...                    ...                  ...         ...   ...      ...
# 6589        Built-up  Area               others      1650.0   1.0      1.0
# 6590  Super built-up  Area               others      1155.0   2.0      1.0
# 6591          Carpet  Area               others      1200.0   2.0      3.0
# 6592  Super built-up  Area               others      1800.0   1.0      1.0
# 6593            Plot  Area               others       812.0   1.0      0.0
#
#       price  bhk  ready_to_move
# 0     428.0    4              0
# 1     194.0    3              0
# 2     235.0    3              1
# 3     130.0    3              0
# 4     148.0    2              0
# ...     ...  ...            ...
# 6589  130.0    2              1
# 6590   64.0    2              1
# 6591   70.0    2              0
# 6592  200.0    1              1
# 6593   26.0    1              0
#
# [6594 rows x 8 columns]
